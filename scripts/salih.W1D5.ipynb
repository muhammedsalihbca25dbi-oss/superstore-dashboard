# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'C:\Users\muham\OneDrive\Desktop\project 4.1\data\samplesuperstore.csv')

# %%
df.shape
# Out:
# (10194, 24)

# %%
df.dtypes
# Out:
# Row ID              int64
# Order ID           object
# Order Date         object
# Ship Date          object
# Ship Mode          object
# Customer ID        object
# Customer Name      object
# Segment            object
# Country/Region     object
# City               object
# State/Province     object
# Postal Code        object
# Region             object
# Product ID         object
# Category           object
# Sub-Category       object
# Product Name       object
# Sales             float64
# Quantity            int64
# Discount          float64
# Profit            float64
# Shipping Days       int64
# Profit Margin     float64
# Order Year          int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country/Region    0
# City              0
# State/Province    0
# Postal Code       0
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# Quantity          0
# Discount          0
# Profit            0
# Shipping Days     0
# Profit Margin     0
# Order Year        0
# dtype: int64

# %%
df[["Sales","Quantity","Discount","Profit"]].describe()
# Out:
#               Sales      Quantity      Discount        Profit
# count  10194.000000  10194.000000  10194.000000  10194.000000
# mean     228.225854      3.791838      0.155385     28.673417
# std      619.906839      2.228317      0.206249    232.465115
# min        0.444000      1.000000      0.000000  -6599.978000
# 25%       17.220000      2.000000      0.000000      1.760800
# 50%       53.910000      3.000000      0.200000      8.690000
# 75%      209.500000      5.000000      0.200000     29.297925
# max    22638.480000     14.000000      0.800000   8399.976000

# %%
print("Duplicate Rows:",df.duplicated().sum())
dupes = df[df.duplicated(subset=["Order ID"], keep=False)]
print(dupes.shape)
dupes.head()
# Out:
# Duplicate Rows: 0
# (7601, 24)
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 1       2  US-2023-112326  2023-01-04  2023-01-08  Standard Class    PO-19195
# 2       3  US-2023-112326  2023-01-04  2023-01-08  Standard Class    PO-19195
# 3       4  US-2023-112326  2023-01-04  2023-01-08  Standard Class    PO-19195
# 5       6  US-2023-167199  2023-01-06  2023-01-10  Standard Class    ME-17320
# 6       7  US-2023-167199  2023-01-06  2023-01-10  Standard Class    ME-17320
#
#    Customer Name      Segment Country/Region        City  ...  \
# 1  Phillina Ober  Home Office  United States  Naperville  ...
# 2  Phillina Ober  Home Office  United States  Naperville  ...
# 3  Phillina Ober  Home Office  United States  Naperville  ...
# 5  Maria Etezadi  Home Office  United States   Henderson  ...
# 6  Maria Etezadi  Home Office  United States   Henderson  ...
#
#           Category Sub-Category                                Product Name  \
# ...

# %%
df["Order Date"] = pd.to_datetime(df["Order Date"])
df["Ship Date"] = pd.to_datetime(df["Ship Date"])
(df.dtypes)
# Out:
# Row ID                     int64
# Order ID                  object
# Order Date        datetime64[ns]
# Ship Date         datetime64[ns]
# Ship Mode                 object
# Customer ID               object
# Customer Name             object
# Segment                   object
# Country/Region            object
# City                      object
# State/Province            object
# Postal Code               object
# Region                    object
# Product ID                object
# Category                  object
# Sub-Category              object
# Product Name              object
# Sales                    float64
# Quantity                   int64
# Discount                 float64
# Profit                   float64
# Shipping Days              int64
# Profit Margin            float64
# Order Year                 int64
# dtype: object

# %%
df["shipping_days"] = (df["Ship Date"] - df["Order Date"]).dt.days
(df.groupby("Region")["shipping_days"].mean().round(1))
# Out:
# Region
# Central    4.1
# East       3.9
# South      4.0
# West       3.9
# Name: shipping_days, dtype: float64

# %%
df["profit_margin"] = (df["Profit"] / df["Sales"] * 100).round(2)
(df.groupby("Sub-Category")["profit_margin"].mean()
    .sort_values(ascending=True).round(1))
# Out:
# Sub-Category
# Binders       -19.5
# Appliances    -14.9
# Tables        -14.0
# Bookcases     -13.5
# Machines       -6.9
# Chairs          4.7
# Storage         9.1
# Supplies       11.4
# Phones         12.2
# Furnishings    14.0
# Accessories    21.8
# Art            25.2
# Fasteners      30.6
# Copiers        32.0
# Envelopes      42.3
# Labels         42.5
# Paper          42.5
# Name: profit_margin, dtype: float64

# %%
df["order_year"] = df["Order Date"].dt.year

# %%
(df)
# Out:
#        Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0           1  US-2023-103800 2023-01-03 2023-01-07  Standard Class
# 1           2  US-2023-112326 2023-01-04 2023-01-08  Standard Class
# 2           3  US-2023-112326 2023-01-04 2023-01-08  Standard Class
# 3           4  US-2023-112326 2023-01-04 2023-01-08  Standard Class
# 4           5  US-2023-141817 2023-01-05 2023-01-12  Standard Class
# ...       ...             ...        ...        ...             ...
# 10189   10190  US-2026-143259 2026-12-30 2027-01-03  Standard Class
# 10190   10191  US-2026-115427 2026-12-30 2027-01-03  Standard Class
# 10191   10192  US-2026-156720 2026-12-30 2027-01-03  Standard Class
# 10192   10193  US-2026-143259 2026-12-30 2027-01-03  Standard Class
# 10193   10194  CA-2026-143500 2026-12-30 2027-01-03  Standard Class
#
#       Customer ID      Customer Name      Segment Country/Region  \
# 0        DP-13000      Darren Powers     Consumer  United States
# ...

# %%
df= df.rename(columns={"Row ID": "row_id", "Order ID": "order_id","Order Date": "order_date","Ship Date": "ship_date","Ship Mode": "ship_mode","Customer ID": "customer_id","Customer Name": "customer_name","Segment": "segment","Country/Region": "country/region","City": "city","Sub-Category": "sub_category","Product Name": "product_name","Sales": "sales","Quantity": "quantity","Discount": "discount","Profit": "profit","Shipping Days": "shipping_days","Profit Margin": "profit_margi","Postal Code": "postal_code","Region": "region","Order Year": "order_year","Product ID": "product_id","Category": "category","Shipping Days": "shipping_days","Profit Margin": "profit_margin","Order Year": "order_year","profit_margin": "profit_margin","shipping_days": "shipping_days","order_year": "order_year"})

# %%
(df.dtypes)
# Out:
# row_id                     int64
# order_id                  object
# order_date        datetime64[ns]
# ship_date         datetime64[ns]
# ship_mode                 object
# customer_id               object
# customer_name             object
# segment                   object
# country/region            object
# city                      object
# State/Province            object
# postal_code               object
# region                    object
# product_id                object
# category                  object
# sub_category              object
# product_name              object
# sales                    float64
# quantity                   int64
# discount                 float64
# profit                   float64
# shipping_days              int64
# profit_margin            float64
# order_year                 int64
# shipping_days              int64
# profit_margin            float64
# order_year                 int32
# dtype: object

# %%
df.to_csv(r'C:\Users\muham\OneDrive\Desktop\project 4.1\data\superstore_clean.csv.csv', index=False)
check = pd.read_csv(r"C:\Users\muham\OneDrive\Desktop\project 4.1\data\superstore_clean.csv.csv")
print("saved Shape:", check.shape)
# Out:
# saved Shape: (10194, 27)
